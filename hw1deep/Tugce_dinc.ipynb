# %%
import matplotlib.pyplot as plt
from PIL import Image

img = Image.open('cat.png')
img = img.convert('RGB')
img
# Out:
# <PIL.Image.Image image mode=RGB size=628x470 at 0x1B9062F7710>

# %%
def flipsimagevertically(image):
    imWidth, imHeight = image.size
    pixelMap = image.load()
    img = Image.new( image.mode, [imWidth, imHeight])
    pixelsNew = img.load()
    for i in range(img.size[0]):
        for j in range(img.size[1]):
            pixelsNew[i, j] = pixelMap[i, imHeight- 1 - j]
            
    return img

imgvertical = flipsimagevertically(img)
imgvertical
# Out:
# <PIL.Image.Image image mode=RGB size=628x470 at 0x1B907EC8940>

# %%
def flipsimagehorizantally(image):
    imWidth, imHeight = image.size
    pixelMap = image.load()
    img = Image.new( image.mode, [imWidth, imHeight])
    pixelsNew = img.load()
    for i in range(img.size[0]):
        for j in range(img.size[1]):
            pixelsNew[i, j] = pixelMap[imWidth - i - 1, j]
            
    return img

imghorizantal = flipsimagehorizantally(img)
imghorizantal
# Out:
# <PIL.Image.Image image mode=RGB size=628x470 at 0x1B907EC8C18>

# %%
def rightby90degree(image):
    imWidth, imHeight = image.size
    pixelMap = image.load()
    img = Image.new(image.mode, [imHeight, imWidth])
    pixelsNew = img.load()
    for i in range(img.size[0]):
        for j in range(img.size[1]):
            pixelsNew[i, j] = pixelMap[j, imHeight - i - 1]
    return img

imgright = rightby90degree(img)
imgright
# Out:
# <PIL.Image.Image image mode=RGB size=470x628 at 0x1B907EC8EB8>

# %%
def leftby90degree(image):
    imWidth, imHeight = image.size
    pixelMap = image.load()
    img = Image.new( image.mode, [imHeight, imWidth])
    pixelsNew = img.load()
    for i in range(img.size[0]):
        for j in range(img.size[1]):
            pixelsNew[i, j] = pixelMap[imWidth - j - 1, i]
    return img

imgleft =  leftby90degree(img)
imgleft
# Out:
# <PIL.Image.Image image mode=RGB size=470x628 at 0x1B907EBE630>

# %%
def resizesinputimagetohalf(image):
    imWidth, imHeight = image.size
    pixelMap = image.load()
    img = Image.new( image.mode, [imWidth//2, imHeight//2])
    pixelsNew = img.load()
    for i in range(img.size[0]):
        for j in range(img.size[1]):
            sum1 = [0,0,0,255]
            for k in range(i*2, i*2 + 2):
                for l in range(j*2, j*2 + 2):
                    temp = pixelMap[k, l]
                    temp = list(temp)
                    sum1[0] = sum1[0] + temp[0]
                    sum1[1] = sum1[1] + temp[1]
                    sum1[2] = sum1[2] + temp[2]
            sum1[0] = sum1[0] //4
            sum1[1] = sum1[1] //4
            sum1[2] = sum1[2] //4
            pixelsNew[i, j] = tuple(sum1)
            
    return img

imghalf = resizesinputimagetohalf(img)
imghalf
# Out:
# <PIL.Image.Image image mode=RGB size=314x235 at 0x1B907EC82E8>

# %%
print(img.size[0], img.size[1], "\n")
print(imghalf.size[0], imghalf.size[1], "\n")
# Out:
# 628 470
#
# 314 235
